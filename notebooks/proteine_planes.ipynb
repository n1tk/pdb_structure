# %%
# !pip3 install biopandas

# %%
from biopandas.pdb import PandasPdb

# %%
#biopandas 1TAW

# %%
# Initialize a new PandasPdb object
# and fetch the PDB file from rcsb.org
ppdb = PandasPdb().fetch_pdb('1TAW')

# %%
data_1TAW = ppdb.df['ATOM']

# %%
data_1TAW
# Out:
#      record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0           ATOM            1                 N                  ILE
# 1           ATOM            2                CA                  ILE
# 2           ATOM            3                 C                  ILE
# 3           ATOM            4                 O                  ILE
# 4           ATOM            5                CB                  ILE
# 5           ATOM            6               CG1                  ILE
# 6           ATOM            7               CG2                  ILE
# 7           ATOM            8               CD1                  ILE
# 8           ATOM            9                 N                  VAL
# 9           ATOM           10                CA                  VAL
# 10          ATOM           11                 C                  VAL
# 11          ATOM           12                 O                  VAL
# ...

# %%
list(data_1TAW)
# Out:
# ['record_name',
#  'atom_number',
#  'blank_1',
#  'atom_name',
#  'alt_loc',
#  'residue_name',
#  'blank_2',
#  'chain_id',
#  'residue_number',
#  'insertion',
#  'blank_3',
#  'x_coord',
#  'y_coord',
#  'z_coord',
#  'occupancy',
#  'b_factor',
#  'blank_4',
#  'segment_id',
#  'element_symbol',
#  'charge',
#  'line_idx']

# %%
data_1TAW.head(5)
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  ILE
# 1        ATOM            2                CA                  ILE
# 2        ATOM            3                 C                  ILE
# 3        ATOM            4                 O                  ILE
# 4        ATOM            5                CB                  ILE
#
#   chain_id  residue_number insertion    ...    x_coord  y_coord  z_coord  \
# 0        A              16              ...     10.627    7.560   19.507
# 1        A              16              ...     10.111    7.564   20.899
# 2        A              16              ...      8.698    8.135   20.828
# 3        A              16              ...      8.507    9.230   20.305
# 4        A              16              ...     10.968    8.475   21.817
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# ...

# %%
new_1TAW = data_1TAW[['atom_name', 'residue_number', 'x_coord', 'y_coord', 'z_coord']]

# %%
new_1TAW.head(20)
# Out:
#    atom_name  residue_number  x_coord  y_coord  z_coord
# 0          N              16   10.627    7.560   19.507
# 1         CA              16   10.111    7.564   20.899
# 2          C              16    8.698    8.135   20.828
# 3          O              16    8.507    9.230   20.305
# 4         CB              16   10.968    8.475   21.817
# 5        CG1              16   12.430    8.008   21.846
# 6        CG2              16   10.383    8.512   23.224
# 7        CD1              16   12.676    6.723   22.608
# 8          N              17    7.720    7.350   21.267
# 9         CA              17    6.314    7.757   21.292
# 10         C              17    5.978    8.193   22.721
# 11         O              17    6.237    7.458   23.678
# 12        CB              17    5.363    6.583   20.938
# 13       CG1              17    3.910    7.060   20.968
# 14       CG2              17    5.709    5.988   19.579
# 15         N              18    5.426    9.388   22.861
# ...

# %%
new_1TAW.shape
# Out:
# (2043, 4)

# %%
# !pip install http://h2o-release.s3.amazonaws.com/h2o/rel-ueno/4/Python/h2o-3.10.4.4-py2.py3-none-any.whl
# Out:
# ...
#     100% |████████████████████████████████| 61.3MB 13.0MB/s ta 0:00:011   0% |                                | 30kB 568kB/s eta 0:01:48    0% |                                | 51kB 867kB/s eta 0:01:11    0% |                                | 71kB 816kB/s eta 0:01:15    0% |                                | 92kB 823kB/s eta 0:01:15    0% |                                | 112kB 866kB/s eta 0:01:11    0% |                                | 133kB 1.2MB/s eta 0:00:52    0% |                                | 153kB 1.1MB/s eta 0:00:55    0% |                                | 174kB 1.3MB/s eta 0:00:47    0% |                                | 194kB 1.7MB/s eta 0:00:36    0% |▏                               | 215kB 1.4MB/s eta 0:00:43    0% |▏                               | 235kB 2.0MB/s eta 0:00:31    0% |▏                               | 256kB 2.1MB/s eta 0:00:29    0% |▏                               | 276kB 2.1MB/s eta 0:00:30    0% |▏                               | 296kB 2.0MB/s eta 0
# ...

# %%
# !pip3 install http://h2o-release.s3.amazonaws.com/h2o/rel-ueno/4/Python/h2o-3.10.4.4-py2.py3-none-any.whl

# %%
import numpy as np
import numpy.linalg as la
 
def py_ang(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'    """
    cosang = np.dot(v1, v2)
    sinang = la.norm(np.cross(v1, v2))
    return np.arctan2(sinang, cosang)

# %%
import numpy as np

a = np.array([32.49, -39.96,-3.86])
b = np.array([31.39, -39.28, -4.66])
c = np.array([31.14, -38.09,-4.49])

ba = a - b
bc = c - b

cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
angle = np.arccos(cosine_angle)

print np.degrees(angle)

# %%
import numpy as np

def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
phrases = ['cat in the park', 'walking my dog']
example = ['I was walking my dog and cat in the park']
vect = CountVectorizer(vocabulary=phrases)

# %%
vect
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=['cat in the park', 'walking my dog'])

# %%
new_1TAW['Atom_combine'] = new_1TAW.atom_name.str.cat(new_1TAW.residue_number.astype(str))
# Out:
# /Users/sbuciuma/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
new_1TAW.head(20)
# Out:
#    atom_name  residue_number  x_coord  y_coord  z_coord Atom_combine
# 0          N              16   10.627    7.560   19.507          N16
# 1         CA              16   10.111    7.564   20.899         CA16
# 2          C              16    8.698    8.135   20.828          C16
# 3          O              16    8.507    9.230   20.305          O16
# 4         CB              16   10.968    8.475   21.817         CB16
# 5        CG1              16   12.430    8.008   21.846        CG116
# 6        CG2              16   10.383    8.512   23.224        CG216
# 7        CD1              16   12.676    6.723   22.608        CD116
# 8          N              17    7.720    7.350   21.267          N17
# 9         CA              17    6.314    7.757   21.292         CA17
# 10         C              17    5.978    8.193   22.721          C17
# 11         O              17    6.237    7.458   23.678          O17
# 12        CB              17    5.363    6.583   20.938         CB17
# ...

# %%
new_1TAW.shape
# Out:
# (2043, 6)

# %%
ready_1TAW = new_1TAW[[ 'Atom_combine', 'x_coord', 'y_coord', 'z_coord']]

# %%
ready_1TAW.shape
# Out:
# (2043, 4)

# %%
ready_1TAW.to_csv('Proteine_1TAW.csv', sep=',')

# %%
# !pwd
# Out:
# /Users/sbuciuma/Desktop/Proteine

# %%
ready_1TAW.head(20)
# Out:
#    Atom_combine  x_coord  y_coord  z_coord
# 0           N16   10.627    7.560   19.507
# 1          CA16   10.111    7.564   20.899
# 2           C16    8.698    8.135   20.828
# 3           O16    8.507    9.230   20.305
# 4          CB16   10.968    8.475   21.817
# 5         CG116   12.430    8.008   21.846
# 6         CG216   10.383    8.512   23.224
# 7         CD116   12.676    6.723   22.608
# 8           N17    7.720    7.350   21.267
# 9          CA17    6.314    7.757   21.292
# 10          C17    5.978    8.193   22.721
# 11          O17    6.237    7.458   23.678
# 12         CB17    5.363    6.583   20.938
# 13        CG117    3.910    7.060   20.968
# 14        CG217    5.709    5.988   19.579
# 15          N18    5.426    9.388   22.861
# 16         CA18    5.054    9.881   24.173
# 17          C18    6.196   10.418   25.015
# 18          O18    6.035   10.617   26.224
# 19          N19    7.336   10.684   24.382

# %%
df = pd.read_csv('Proteine_1TAW.csv')
df
# Out:
#       Unnamed: 0 Atom_combine  x_coord  y_coord  z_coord
# 0              0          N16   10.627    7.560   19.507
# 1              1         CA16   10.111    7.564   20.899
# 2              2          C16    8.698    8.135   20.828
# 3              3          O16    8.507    9.230   20.305
# 4              4         CB16   10.968    8.475   21.817
# 5              5        CG116   12.430    8.008   21.846
# 6              6        CG216   10.383    8.512   23.224
# 7              7        CD116   12.676    6.723   22.608
# 8              8          N17    7.720    7.350   21.267
# 9              9         CA17    6.314    7.757   21.292
# 10            10          C17    5.978    8.193   22.721
# 11            11          O17    6.237    7.458   23.678
# 12            12         CB17    5.363    6.583   20.938
# 13            13        CG117    3.910    7.060   20.968
# 14            14        CG217    5.709    5.988   19.579
# ...

# %%
from scipy.spatial.distance import cdist
import numpy as np

# %%
X = np.array(df[['x_coord', 'y_coord', 'z_coord']])
D = cdist(X, X, metric='euclidean') # your distance matrix

# %%
atom_df = pd.DataFrame(D, index=list(df['Atom_combine']), columns=list(df['Atom_combine']))

# %%
atom_df
# Out:
#              N16       CA16        C16        O16       CB16      CG116  \
# N16     0.000000   1.484566   2.407635   2.814268   2.507909   2.987044
# CA16    1.484566   0.000000   1.525664   2.387720   1.551481   2.543955
# C16     2.407635   1.525664   0.000000   1.228428   2.499324   3.870436
# O16     2.814268   2.387720   1.228428   0.000000   2.985413   4.388382
# CB16    2.507909   1.551481   2.499324   2.985413   0.000000   1.535049
# CG116   2.987044   2.543955   3.870436   4.388382   1.535049   0.000000
# CG216   3.844727   2.525532   2.953332   3.543369   1.524219   2.518553
# CD116   3.809878   3.194869   4.581116   5.382325   2.571468   1.514062
# N17     3.404754   2.428601   1.328695   2.253711   3.481038   4.790856
# CA17    4.671938   3.822160   2.457974   2.820132   4.738234   6.146167
# C17     5.687151   4.560374   3.314395   3.648050   5.079059   6.513690
# O17     6.056381   4.768852   3.825879   4.435089   5.184590   6.481664
# ...

# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
# !pip3 install keras --upgrade
# Out:
# ...
#   Using cached Keras-2.0.3.tar.gz
# ...
#   Using cached Theano-0.9.0.tar.gz
# Requirement already up-to-date: pyyaml in /Users/sbuciuma/anaconda/lib/python3.5/site-packages (from keras)
# Requirement already up-to-date: six in /Users/sbuciuma/anaconda/lib/python3.5/site-packages (from keras)
# Requirement already up-to-date: numpy>=1.9.1 in /Users/sbuciuma/anaconda/lib/python3.5/site-packages (from theano->keras)
# Requirement already up-to-date: scipy>=0.14 in /Users/sbuciuma/anaconda/lib/python3.5/site-packages (from theano->keras)
# ...
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/93/72/65/4924fd6b1859343291c50774e2df36919ee61c4511dc6a9890
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/d5/5b/93/433299b86e3e9b25f0f600e4e4ebf18e38eb7534ea518eba13
# Successfully built keras theano
# ...
#   Found existing installation: Theano 0.8.2
#     Uninstalling Theano-0.8.2:
#       Successfully uninstalled Theano-0.8.2
# ...

# %%
from keras.models import Sequential

# %%
# !pip3 install gspread
# Out:
# ...
#   Using cached gspread-0.6.2.tar.gz
# ...
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/d8/1a/20/103b4431b5d3993d907dca9d06a9b05f59d62ecc1a8f3a6fd2
# Successfully built gspread
# ...

# %%
import nltk

# %%
# !pip3 install BiologicalProcessNetworks
# Out:
# ...
#     92% |█████████████████████████████▊  | 102kB 392kB/s eta 0:00:01K    18% |██████                          | 20kB 438kB/s eta 0:00:01    37% |███████████▉                    | 40kB 362kB/s eta 0:00:01    55% |█████████████████▉              | 61kB 407kB/s eta 0:00:01    83% |██████████████████████████▊     | 92kB 400kB/s eta 0:00:01    100% |████████████████████████████████| 112kB 411kB/s
# ...
#     90% |█████████████████████████████   | 40kB 395kB/s eta 0:00:01    45% |██████████████▌                 | 20kB 429kB/s eta 0:00:01    100% |████████████████████████████████| 51kB 458kB/s
# ...
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/58/79/ce/9e91e34c51d2b08cf2d66a131cec664e7382a987e7746cb2cf
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/4f/70/ef/535e34cb9c77c767c4b56be21dfcb6fb2f3465fc9c7b26d327
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/a4/79/f7/58108a17748de3dc72ec44d156b6467547e2aaa50364764274
# done
# ...

# %%
# !pip3 install -U ProDy
# Out:
# ...
#     100% |████████████████████████████████| 983kB 206kB/s ta 0:00:01K    3% |█                               | 30kB 116kB/s eta 0:00:09    6% |██                              | 61kB 139kB/s eta 0:00:07    9% |███                             | 92kB 164kB/s eta 0:00:06    11% |███▊                            | 112kB 175kB/s eta 0:00:05    14% |████▊                           | 143kB 222kB/s eta 0:00:04    17% |█████▊                          | 174kB 189kB/s eta 0:00:05    19% |██████▍                         | 194kB 196kB/s eta 0:00:04    23% |███████▍                        | 225kB 209kB/s eta 0:00:04    26% |████████▍                       | 256kB 199kB/s eta 0:00:04    28% |█████████                       | 276kB 209kB/s eta 0:00:04    31% |██████████                      | 307kB 241kB/s eta 0:00:03    33% |██████████▊                     | 327kB 198kB/s eta 0:00:04    36% |███████████▊                    | 358kB 177kB/s eta 0:00:04    38% |████████████▍                   | 378kB 19
# ...

# %%
#http://stackoverflow.com/questions/11685716/how-to-extract-chains-from-a-pdb-file
import os
from Bio import PDB


class ChainSplitter:
    def __init__(self, out_dir=None):
        """ Create parsing and writing objects, specify output directory. """
        self.parser = PDB.PDBParser()
        self.writer = PDB.PDBIO()
        if out_dir is None:
            out_dir = os.path.join(os.getcwd(), "chain_PDBs")
        self.out_dir = out_dir

    def make_pdb(self, pdb_path, chain_letters, overwrite=False, struct=None):
        """ Create a new PDB file containing only the specified chains.

        Returns the path to the created file.

        :param pdb_path: full path to the crystal structure
        :param chain_letters: iterable of chain characters (case insensitive)
        :param overwrite: write over the output file if it exists
        """
        chain_letters = [chain.upper() for chain in chain_letters]

        # Input/output files
        (pdb_dir, pdb_fn) = os.path.split(pdb_path)
        pdb_id = pdb_fn[3:7]
        out_name = "pdb%s_%s.ent" % (pdb_id, "".join(chain_letters))
        out_path = os.path.join(self.out_dir, out_name)
        print "OUT PATH:",out_path
        plural = "s" if (len(chain_letters) > 1) else ""  # for printing

        # Skip PDB generation if the file already exists
        if (not overwrite) and (os.path.isfile(out_path)):
            print("Chain%s %s of '%s' already extracted to '%s'." %
                    (plural, ", ".join(chain_letters), pdb_id, out_name))
            return out_path

# %%
#http://stackoverflow.com/questions/40082685/pdb-biopython-extracting-the-coordinates?rq=1
from Bio.PDB import PDBParser


p = PDBParser()
s = p.get_structure("4K5Y", "4K5Y.pdb")                    

for chains in s:
    for chain in chains:
        for residue in chain:                             
            for atom in residue:
                print(atom.get_vector())

# %%
# !conda install numpy biopython matplotlib pip
# Out:
# Fetching package metadata ...........
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /Users/sbuciuma/anaconda:
# #

# %%
# !pip3 install docopt
# Out:
# ...
#   Using cached docopt-0.6.2.tar.gz
# ...
# done
#   Stored in directory: /Users/sbuciuma/Library/Caches/pip/wheels/b2/16/5f/c33a2bb5f2dce71205f8e65cbfd05647d79d441282be31fd82
# Successfully built docopt
# ...

# %%
mainchain = ppdb.df['ATOM'][(ppdb.df['ATOM']['atom_name'] == 'C')|
                            (ppdb.df['ATOM']['atom_name'] == 'O')|
                            (ppdb.df['ATOM']['atom_name'] == 'N')|
                            (ppdb.df['ATOM']['atom_name'] == 'CA')]

# %%
mainchain
# Out:
#      record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0           ATOM            1                 N                  ILE
# 1           ATOM            2                CA                  ILE
# 2           ATOM            3                 C                  ILE
# 3           ATOM            4                 O                  ILE
# 8           ATOM            9                 N                  VAL
# 9           ATOM           10                CA                  VAL
# 10          ATOM           11                 C                  VAL
# 11          ATOM           12                 O                  VAL
# 15          ATOM           16                 N                  GLY
# 16          ATOM           17                CA                  GLY
# 17          ATOM           18                 C                  GLY
# 18          ATOM           19                 O                  GLY
# ...

# %%
bfact_mc_avg = mainchain['b_factor'].mean()
print('Average B-Factor [Main Chain]: %.2f' % bfact_mc_avg)
